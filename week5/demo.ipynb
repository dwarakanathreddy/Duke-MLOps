# %% [markdown]
# <a href="https://colab.research.google.com/github/dwarakanathreddy/Duke-MLOps/blob/main/week5/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## importing the libraries

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/live/us-states.csv")
data.head(5)
# Out:
#          date          state  fips    cases  deaths
# 0  2023-03-24      Tennessee    47  2459152   29035
# 1  2023-03-24       Michigan    26  3068195   42311
# 2  2023-03-24  Massachusetts    25  2230150   24441
# 3  2023-03-24       Maryland    24  1369930   16672
# 4  2023-03-24           Iowa    19   907421   10770
